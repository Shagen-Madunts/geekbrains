# %% [markdown]
# # Урок 2

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# __1.__ Представьте в виде __несократимой__ рациональной дроби:
#
# ### $$а)\,\,\, 0.(216);$$
# ### $$с=0.(216)$$
# ### $$1000с=216.(216)$$
# ### $$1000с=216+0.(216)$$
# ### $$1000с=216 + с$$
# ### $$с=\frac{216}{999}=\frac{24}{111}$$
# ### $$0.(216)=\frac{24}{111}$$
#
#
#
#
#
# ### $$б)\,\,\, 1.0(01).$$
# ### $$с=1.0(01)$$
#
# ### $$100с=101(01)$$
#
# ### $$100с=100+1.(01)$$
#
# ### $$100с=100+с$$
#
# ### $$с=\frac{100}{99} = 1\frac{1}{99}$$
#
# ### $$1.0(01)=1\frac{1}{99}$$

# %%
# проверка
print(24/111)
print(1 + 1/99)
# Out:
# 0.21621621621621623
# 1.0101010101010102

# %% [markdown]
# __2*.__ Пусть $x =\frac{2}{21}$. Известно, что для некоторого натурального $k$ число $x$ записывается в $k$ - ичной системе счисления как $0.(13)_k = 0, 131313_k$. Найдите $k$.

# %% [markdown]
# > **Решение**:
# k должно быть > 10, потому что в 10-й системе x = 0.09, а в к-й системе 0.013
# $$ x = \Bigg(\frac{2}{21}\Bigg) $$
# $$ x = 0.(13)$$
# ==>
# $$ k^2x = 13*(13)_k$$
# ==>
# $$ x = \frac{13_k}{k^2 - 1 } $$
# ==>
# $$ \frac{2}{21} = \frac{13_k}{k^2 - 1 }$$
# ==>
# $$ 2k^2 -21k - 65 = 0$$
# ==> k = 13

# %% [markdown]
# __3.__ Проверьте любым способ, является ли данные логические формулы тавтологией:
#
#
# > $$a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A)$$
# > **Решение**:
#  Решим с помощью таблицы истинности:
#
#  <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\vee B$</th><th>$\overline A$</th><th>$ B\vee \overline A$</th><th>$(A\vee B) \rightarrow ( B\vee \overline A)$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
# При любых $A$ и $B$ мы не получаем истинное значение. Следовательно, формула не является тавтологией.
#
#
#
# >$$б)\,\,\, A \rightarrow (A \vee (\overline B \wedge A))$$
# > **Решение**:
#  Решим с помощью таблицы истинности:
#
#  <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$\overline B$</th><th>$\overline B\vee A$</th><th>$ A\vee (\overline B\vee A)$</th><th>$A \rightarrow (A\vee (\overline B\vee A))$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
# При любых $A$ и $B$ мы получаем истинное значение. Следовательно, формула является тавтологией.

# %% [markdown]
# __4.__ Сформулируйте словесно высказывания:
# > $$a)\,\,\, (\overline A \vee B) \rightarrow \overline C$$
# > **Решение**:
# Если сегодня не светит солнце либо сегодня сыро, то я не поеду на дачу
#
# > $$б)\,\,\, C \rightarrow (A \vee \overline B)$$
# > **Решение**:
# Если я поеду на дачу, то сегодня светит солнце либо сегодня не сыро
#
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.

# %% [markdown]
# __5.__  Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:
#
# a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
#
# $\forall$ курсе $\forall$ факультета $\exists$ студенты, __сдающие__ $\forall$ экзамены на «отлично».
#
# $\exists$ курсе $\exists$ факультета $\forall$ студенты, __не сдающие__ $\exists$ экзамены на «отлично».
#
# Есть курс на одном факультете, где все студенты не сдают существующие экзамены на «отлично».
#
# б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.
#
# В $\forall$ самолете на рейсе Вашингтон-Москва $\exists$ сотрудник силовых органов, в $\forall$ пуговице которого вмонтирован микрофон.
#
# В $\exists$ самолете на рейсе Вашингтон-Москва $\forall$ сотрудник силовых органов, в $\exists$ пуговице которого __вмонтирован__ микрофон.
#
# Есть самолеты рейса Вашингтон-Москва, где каждому сотруднику силовых органов в одной из пуговиц не вмонтирован микрофон.
