# %% [markdown]
# # Задание 1

# %% [markdown]
# > **Вычислить**:
# $$7*\begin{bmatrix} 5 & 10 \\ 7 & 12 \\ 11.3 & 5 \\ 25 & 30 \end{bmatrix} +2*\begin{bmatrix} 5 & 10 \\ 7 & 12 \\ 11.3 & 5 \\ 25 & 30 \end{bmatrix}$$
#
# > **Ответ**:
# $$\begin{bmatrix} 45 & 90 \\ 63 & 108 \\ 101.7 & 45 \\ 225 & 270 \end{bmatrix}$$

# %% [markdown]
# # Задание 2

# %% [markdown]
# > **Решить сиcтему уравнений**:
# $$ 3x – 2y + 5z = 7 $$
# $$ 7x + 4y – 8z = 3 $$
# $$ 5x – 3y – 4z = –12 $$
# Линейная или нелинейная это система? А каждое уравнение по отдельности?
#
# > **Ответ**:
# $$ 2y = 3x+5z-7$$
# ==>
# $$ 13x+2z = 17$$
# $$ x-23z = -45$$
# ==>
# $$ x= 1$$
# $$ y= 3$$
# $$ z= 2$$
# Это система линейная. Каждое уравнение в системе тоже линойное.

# %% [markdown]
# # Задание 3

# %% [markdown]
# > **Решить систему уравнений**:
# $$ x^2 + yx – 9 = 0 $$
# $$ x – \frac15y = 0 $$
# Линейная или нелинейная это система?  А каждое уравнение по отдельности?
#
# > **Ответ**:
# $$ y = 5x $$
# $$ 6x^2 = 9  ==> $$
# $$x= \sqrt\frac32 ==> y= 5\sqrt\frac32  $$
# Это система нелинейная, потому что в составе имеется по крайней мере одно уравнение степени не ниже второй. Первое уравнение нелинейное, второе линейное

# %% [markdown]
# # Задание 4

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# %%
x = np.linspace(1, 10, 101)
plt.plot(x, np.sin(x), label='sin(x)')
plt.plot(x, np.sin(2*x), label='sin(2x)')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(bbox_to_anchor=(1.05, 1), loc='lower right', borderaxespad=0.)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
